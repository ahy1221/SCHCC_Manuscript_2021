# %% [markdown]
# # Function

# %%
suppressPackageStartupMessages({
  library(tidyverse)
  library(scater)
})

readCellphoneDB <- function(sample) {
  deconfile = "deconvoluted.txt"
  meanfile = "means.txt"
  pvaluefile = "pvalues.txt"
  significantfile = "significant_means.txt"
  #sample = "./data/pipeline_output/cellphonedb/SS2-D20171109"
  decon <- as.data.frame(readr::read_tsv(file.path(sample, deconfile), guess_max = 10000))
  means <- as.data.frame(readr::read_tsv(file.path(sample, meanfile), guess_max = 10000))
  sig <- as.data.frame(readr::read_tsv(file.path(sample, significantfile),guess_max = 10000))
  pvalues <- as.data.frame(readr::read_tsv(file.path(sample, pvaluefile), guess_max = 10000)  )
  
  
  
  interact_meta <- means[,1:11]
  means <- as.matrix(means[, 12:ncol(means)])

  pvalue_meta <- pvalues[, 1:11]
  pvalues <- as.matrix(pvalues[, 12:ncol(pvalues)])
  
  sig_ranks <- sig[, 1:12]
  sig <- as.matrix(sig[, 13:ncol(sig)])
  
  


    
  # Assign rownames
  rownames(sig_ranks) <- sig_ranks$id_cp_interaction
  rownames(sig) <- sig_ranks$id_cp_interaction  
 rownames(pvalues) <- pvalue_meta$id_cp_interaction
  rownames(means) <- interact_meta$id_cp_interaction
  rownames(interact_meta) <- interact_meta$id_cp_interaction

    
  #--- Filter rank
  keep <- rownames(sig_ranks)[which(sig_ranks$rank < 1)]
  
  means <- means[keep, ]    
  sig <- sig[keep, ]
  pvalues <- pvalues[keep,]
  interact_meta <- interact_meta[keep,]
  sig_ranks <- sig_ranks[keep, ]
        


  # filter complex pair
    
  keep <- rownames(sig_ranks)[which(!grepl("complex", sig_ranks$interacting_pair))]
  means <- means[keep, ]    
  sig <- sig[keep, ]
  pvalues <- pvalues[keep,]
  interact_meta <- interact_meta[keep,]
  sig_ranks <- sig_ranks[keep, ]


  
 
    
  return(list(mean = means, pvalue = pvalues, significant = sig, significant_rank = sig_ranks, meta = interact_meta))
}




getSignificantPairs <- function(cpdb.list, pvalue.cutoff = 0.01) {
  sig <- cpdb.list$significant
  means <- cpdb.list$mean
  pvalues <- cpdb.list$pvalue
  meta <- cpdb.list$meta
  
  
  plotdata <- setNames(reshape2::melt(pvalues), c("id_cp_interaction", "cluster_pair", "pvalue")) 
  plotdata <- left_join(plotdata, setNames(reshape2::melt(means), c("id_cp_interaction", "cluster_pair", "mean")) ) 
  plotdata <- left_join(plotdata, meta)
  plotdata <- plotdata %>% 
   filter(pvalue < pvalue.cutoff) %>% 
   #arrange(desc(rank)) %>% 
   
   #dplyr::mutate(pvalue_plot = ifelse(pvalue == 0, 0.0009, pvalue)) %>% 
   dplyr::mutate(cluster_a = sapply(strsplit(as.character(cluster_pair), "\\|"), `[[`, 1),
           cluster_b = sapply(strsplit(as.character(cluster_pair), "\\|"), `[[`, 2)) %>% 
   filter(cluster_a != cluster_b) 
  return(plotdata)
}

# %% [markdown]
# # Read CellphoneDB interaction Result

# %%
cpdb_res <- readCellphoneDB(file.path("./out/AlltoAll_Avg1_simplified_latest/"))
topInteract <- getSignificantPairs(cpdb_res, pvalue.cutoff = 0.01)
# Out:
# ── Column specification ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# cols(
#   .default = col_double(),
#   gene_name = col_character(),
#   uniprot = col_character(),
#   is_complex = col_logical(),
#   protein_name = col_character(),
#   complex_name = col_character(),
#   id_cp_interaction = col_character()
# )
# ℹ Use `spec()` for the full column specifications.
#
#
#
# ── Column specification ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# cols(
#   .default = col_double(),
#   id_cp_interaction = col_character(),
#   interacting_pair = col_character(),
#   partner_a = col_character(),
#   partner_b = col_character(),
#   gene_a = col_character(),
#   gene_b = col_character(),
#   secreted = col_logical(),
#   receptor_a = col_logical(),
#   receptor_b = col_logical(),
#   annotation_strategy = col_character(),
#   is_integrin = col_logical()
# )
# ℹ Use `spec()` for the full column specifications.
#
#
#
# ── Column specification ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# cols(
#   .default = col_double(),
#   id_cp_interaction = col_character(),
#   interacting_pair = col_character(),
#   partner_a = col_character(),
#   partner_b = col_character(),
#   gene_a = col_character(),
#   gene_b = col_character(),
#   secreted = col_logical(),
#   receptor_a = col_logical(),
#   receptor_b = col_logical(),
#   annotation_strategy = col_character(),
#   is_integrin = col_logical()
# )
# ℹ Use `spec()` for the full column specifications.
#
#
#
# ── Column specification ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# cols(
#   .default = col_double(),
#   id_cp_interaction = col_character(),
#   interacting_pair = col_character(),
#   partner_a = col_character(),
#   partner_b = col_character(),
#   gene_a = col_character(),
#   gene_b = col_character(),
#   secreted = col_logical(),
#   receptor_a = col_logical(),
#   receptor_b = col_logical(),
#   annotation_strategy = col_character(),
#   is_integrin = col_logical()
# )
# ℹ Use `spec()` for the full column specifications.
#
#
# Joining, by = c("id_cp_interaction", "cluster_pair")
#
# Joining, by = "id_cp_interaction"

# %%
sce <- readRDS("../../data/expression/sce/sce_Smartseq2_scHCC-CD45_featureCounts_qc_clustered_analysed.rds")

# %% [markdown]
# ## TPM

# %%
assay(sce, "logtpm") <- log2(scater::calculateTPM(sce, rowData(sce)$Length) + 1)

# %% [markdown]
# # Retain only ligand-receptor interactions

# %%
topInteract_clean <- topInteract %>% 
    filter( !(receptor_a & receptor_b)) %>% 
    filter( !(!receptor_a  & !receptor_b)) %>% 
    filter(!grepl("complex", partner_b)) %>% 
    filter(!grepl("complex", partner_a)) %>% 
 mutate(sending = case_when(
        receptor_a & !receptor_b ~ cluster_b, 
        !receptor_a & receptor_b ~ cluster_a
    ),
    ligand = case_when(
        receptor_a & !receptor_b ~ gene_b, 
        !receptor_a & receptor_b ~ gene_a
    )) %>% 
mutate(receiver = case_when(
        receptor_a & !receptor_b ~ cluster_a, 
        !receptor_a & receptor_b ~ cluster_b
        ),
    receptor = case_when(
        receptor_a & !receptor_b ~ gene_a, 
        !receptor_a & receptor_b ~ gene_b
    ))

# %%
topInteract_clean$sending <- gsub("\\.", "-", topInteract_clean$sending)
topInteract_clean$receiver <- gsub("\\.", "-", topInteract_clean$receiver)

# %%
topInteract_clean$sending <- gsub("B-Cell", "B Cell", topInteract_clean$sending)
topInteract_clean$receiver <- gsub("B-Cell", "B Cell", topInteract_clean$receiver)

topInteract_clean$sending <- gsub("Plasma-B Cell", "Plasma B Cell", topInteract_clean$sending)
topInteract_clean$receiver <- gsub("Plasma-B Cell", "Plasma B Cell", topInteract_clean$receiver)

topInteract_clean$sending <- gsub("CD4-CD8-C1-CCR7", "CD4/CD8-C1-CCR7", topInteract_clean$sending)
topInteract_clean$receiver <- gsub("CD4-CD8-C1-CCR7", "CD4/CD8-C1-CCR7", topInteract_clean$receiver)
topInteract_clean$sending <- gsub("CD4-CD8-C2-MKI67", "CD4/CD8-C2-MKI67", topInteract_clean$sending)
topInteract_clean$receiver <- gsub("CD4-CD8-C2-MKI67", "CD4/CD8-C2-MKI67", topInteract_clean$receiver)

# %% [markdown]
# # Gather expression information

# %%
lr_genes <- unique(c(topInteract_clean$ligand , topInteract_clean$receptor))

# %%
exprDF <- makePerCellDF(sce, features = lr_genes, assay.type = "logtpm")
exprDF[which(grepl("^HCC", exprDF$celltype)), "celltype"] <- "HCC_Malignant"

# %%
table(topInteract_clean$sending)
# Out:
#             B Cell           CAF_CD36            CAF_LUM          CAF_NTRK2
#                570               1058               1477               1051
#       CD4-C3-ANXA1        CD4-C4-IL7R        CD4-C5-TCF7      CD4-C6-CXCL13
#                406                552                618                669
#       CD4-C7-FOXP3    CD4/CD8-C1-CCR7   CD4/CD8-C2-MKI67        CD8-C3-IL7R
#                443                354               1091                309
#      CD8-C4-CX3CR1        CD8-C5-SELL        CD8-C6-GZMK       CD8-C7-KLRD1
#                314                347                551                543
#       CD8-C8-PDCD1     CD8-C9-SLC4A10 cHCC_ICC_D20171229         DC-C1-CD1C
#                771                571               1240               1159
#       DC-C2-FCER1A       DC-C3-CLEC9A        DC-C4-LAMP3    Endo_C01_CLEC4G
#               1071               1102                971                999
#     Endo_C02_ACKR1     Endo_C03_GABRD      Endo_C04_FMO2    Endo_C05_CXCL12
#               1605               1613               1341               1532
#      HCC_Malignant        Hepatocytes               hLPS      ICC_D20171215
#               1039                459               1085               1378
#               ILCs       Mast-C1-IL7R       Mast-C2-CPA3       Mono-C1-CD14
#                700                739                936                758
#     Mono-C2-FCGR3A      Mphi-C1-THBS1       Mphi-C2-C1QA       Mphi-C5-VCAN
#               1030                998               1342                900
#      Mphi-C6-MARCO       NK-C1-FCGR3A         NK-C2-SELL         NK-C3-IFNG
#               1072                424                485                679
#         NK-C5-CD69         NK-C6-IL7R        NK-C7-CD160        NK-C9-MKI67
#                543                508                685                675
#      Plasma B Cell
#                607

# %%
exprDF <- exprDF %>% 
    select(celltype, lr_genes) %>% 
    pivot_longer(cols = lr_genes , names_to = "gene",  values_to = "logtpm") %>%
    group_by(celltype, gene) %>%
    summarise( fractionExpr = sum(logtpm > 0)/n(), meanExpr = mean(logtpm) )
# Out:
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(lr_genes)` instead of `lr_genes` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
#
# `summarise()` has grouped output by 'celltype'. You can override using the `.groups` argument.

# %%
topInteract_clean <- topInteract_clean %>% 
    left_join(exprDF,  by = c("sending" = "celltype", "ligand" = "gene") ) %>%
    dplyr::rename(fractionExprLigand = fractionExpr, meanExprLigand = meanExpr) %>%
    left_join(exprDF,  by = c("receiver" = "celltype", "receptor" = "gene") ) %>%
    dplyr::rename(fractionExprReceptor = fractionExpr, meanExprReceptor = meanExpr)

# %%
topInteract_filtered <- topInteract_clean %>% 
    filter(meanExprLigand > 2 & meanExprReceptor > 2)

# %%
topInteract_filtered %>% 
   mutate(LR = paste0(ligand, "-", receptor)) %>%
   filter(grepl("Endo_C05_CXCL12", sending )) %>%  
   filter(grepl("^CAF", receiver))
# Out:
#    id_cp_interaction cluster_pair              pvalue mean  interacting_pair
# 1  CPI-SS0C4D54E39   CAF_CD36|Endo_C05_CXCL12  0      6.131 NOTCH3_JAG2
# 2  CPI-SS0E5AF12B6   CAF_CD36|Endo_C05_CXCL12  0      3.889 NOTCH1_NOV
# 3  CPI-SS08C3D27F7   CAF_CD36|Endo_C05_CXCL12  0      3.891 NOTCH1_JAG2
# 4  CPI-SS0D954EA1C   CAF_CD36|Endo_C05_CXCL12  0      6.694 PDGFRB_PDGFD
# 5  CPI-SS012B7C21D   CAF_CD36|Endo_C05_CXCL12  0      5.351 NOTCH1_DLL4
# 6  CPI-SS0B87FE6E0   CAF_CD36|Endo_C05_CXCL12  0      5.236 NOTCH1_JAG1
# 7  CPI-SS03A4F7DC8   CAF_CD36|Endo_C05_CXCL12  0      6.618 AXL_GAS6
# 8  CPI-SS01A07768A   CAF_CD36|Endo_C05_CXCL12  0      6.231 CD46_JAG1
# 9  CPI-SS034D36D2F   CAF_CD36|Endo_C05_CXCL12  0      6.468 HLA-C_FAM3C
# 10 CPI-SS0DA033F03   CAF_CD36|Endo_C05_CXCL12  0      7.050 TNFRSF1A_GRN
# 11 CPI-SS0C4E86714   CAF_CD36|Endo_C05_CXCL12  0      5.425 TNFRSF1B_GRN
# 12 CPI-SS0C4D54E39   CAF_LUM|Endo_C05_CXCL12   0      4.466 NOTCH3_JAG2
# 13 CPI-SS0E5AF12B6   CAF_LUM|Endo_C05_CXCL12   0      3.747 NOTCH1_NOV
# 14 CPI-SS08C3D27F7   CAF_LUM|Endo_C05_CXCL12   0      3.749 NOTCH1_JAG2
# 15 CPI-SS0D954EA1C   CAF_LUM|Endo_C05_CXCL12   0      6.150 PDGFRB_PDGFD
# 16 CPI-SS012B7C21D   CAF_LUM|Endo_C05_CXCL12   0      5.210 NOTCH1_DLL4
# 17 CPI-SS02770D68F   CAF_LUM|Endo_C05_CXCL12   0      4.959 NOTCH2_JAG2
# 18 CPI-SS0B87FE6E0   CAF_LUM|Endo_C05_CXCL12   0      5.094 NOTCH1_JAG1
# 19 CPI-SS027CDEA08   CAF_LUM|Endo_C05_CXCL12   0      6.419 NOTCH2_DLL4
# 20 CPI-SS03A4F7DC8   CAF_LUM|Endo_C05_CXCL12   0      5.577 AXL_GAS6
# 21 CPI-SS08CA619FE   CAF_LUM|Endo_C05_CXCL12   0      6.137 EGFR_GRN
# 22 CPI-SS088A0A760   CAF_LUM|Endo_C05_CXCL12   0      4.283 EGFR_COPA
# 23 CPI-SS00EDDD458   CAF_LUM|Endo_C05_CXCL12   0      3.851 EGFR_MIF
# 24 CPI-SS01A07768A   CAF_LUM|Endo_C05_CXCL12   0      6.006 CD46_JAG1
# 25 CPI-SS0DA033F03   CAF_LUM|Endo_C05_CXCL12   0      7.419 TNFRSF1A_GRN
# 26 CPI-SS0C4D54E39   CAF_NTRK2|Endo_C05_CXCL12 0      6.067 NOTCH3_JAG2
# 27 CPI-SS07155793F   CAF_NTRK2|Endo_C05_CXCL12 0      4.398 ACKR3_CXCL12
# 28 CPI-SS0D954EA1C   CAF_NTRK2|Endo_C05_CXCL12 0      6.244 PDGFRB_PDGFD
# 29 CPI-SS02770D68F   CAF_NTRK2|Endo_C05_CXCL12 0      4.120 NOTCH2_JAG2
# 30 CPI-SS027CDEA08   CAF_NTRK2|Endo_C05_CXCL12 0      5.580 NOTCH2_DLL4
# ⋮  ⋮                 ⋮                         ⋮      ⋮     ⋮
# 58 CPI-SS05A26A1DE   Endo_C05_CXCL12|CAF_LUM   0      5.610 PDGFB_PDGFRB
# 59 CPI-SS09CA492BA   Endo_C05_CXCL12|CAF_LUM   0      6.834 EFNA1_EPHA3
# 60 CPI-SS03DA2A820   Endo_C05_CXCL12|CAF_LUM   0      3.322 FGF2_CD44
# 61 CPI-SS048346C2B   Endo_C05_CXCL12|CAF_LUM   0      4.684 LGALS9_MRC2
# 62 CPI-SS02928C71A   Endo_C05_CXCL12|CAF_LUM   0      5.158 PDGFB_LRP1
# 63 CPI-SS0C85BC9AF   Endo_C05_CXCL12|CAF_LUM   0      4.533 PROS1_AXL
# 64 CPI-SS006C6537E   Endo_C05_CXCL12|CAF_LUM   0      6.145 MDK_LRP1
# 65 CPI-SS0BD9F32BA   Endo_C05_CXCL12|CAF_LUM   0      3.691 LGALS9_DAG1
# 66 CPI-SS0A9FB762A   Endo_C05_CXCL12|CAF_LUM   0      3.926 LGALS9_PTPRK
# 67 CPI-SS060B82BBC   Endo_C05_CXCL12|CAF_LUM   0      6.304 JAG1_NOTCH2
# 68 CPI-SS0FF49C823   Endo_C05_CXCL12|CAF_LUM   0      5.404 EFNA1_EPHA1
# 69 CPI-SS0419B80C4   Endo_C05_CXCL12|CAF_LUM   0      5.961 LGALS9_LRP1
# 70 CPI-SS002DF6C31   Endo_C05_CXCL12|CAF_LUM   0      3.502 LGALS9_SLC1A5
# 71 CPI-SS014958F32   Endo_C05_CXCL12|CAF_LUM   0      4.754 LGALS9_CD47
# 72 CPI-SS0703338F5   Endo_C05_CXCL12|CAF_LUM   0      4.385 LGALS9_CD44
# 73 CPI-SS0F21DBF93   Endo_C05_CXCL12|CAF_NTRK2 0      4.534 SCGB3A1_NOTCH3
# 74 CPI-SS0938C6980   Endo_C05_CXCL12|CAF_NTRK2 0      7.527 DLL4_NOTCH3
# 75 CPI-SS0B99F22A2   Endo_C05_CXCL12|CAF_NTRK2 0      7.412 JAG1_NOTCH3
# 76 CPI-SS05A26A1DE   Endo_C05_CXCL12|CAF_NTRK2 0      5.704 PDGFB_PDGFRB
# 77 CPI-SS09CA492BA   Endo_C05_CXCL12|CAF_NTRK2 0      5.339 EFNA1_EPHA3
# 78 CPI-SS03DA2A820   Endo_C05_CXCL12|CAF_NTRK2 0      3.081 FGF2_CD44
# 79 CPI-SS0C85BC9AF   Endo_C05_CXCL12|CAF_NTRK2 0      5.522 PROS1_AXL
# 80 CPI-SS0BD9F32BA   Endo_C05_CXCL12|CAF_NTRK2 0      4.042 LGALS9_DAG1
# 81 CPI-SS0A9FB762A   Endo_C05_CXCL12|CAF_NTRK2 0      4.274 LGALS9_PTPRK
# 82 CPI-SS060B82BBC   Endo_C05_CXCL12|CAF_NTRK2 0      5.464 JAG1_NOTCH2
# 83 CPI-SS0FF49C823   Endo_C05_CXCL12|CAF_NTRK2 0      5.733 EFNA1_EPHA1
# 84 CPI-SS04F3A1E5C   Endo_C05_CXCL12|CAF_NTRK2 0      5.217 COPA_SORT1
# 85 CPI-SS07CCAD9BF   Endo_C05_CXCL12|CAF_NTRK2 0      7.072 GRN_SORT1
# 86 CPI-SS014958F32   Endo_C05_CXCL12|CAF_NTRK2 0      4.046 LGALS9_CD47
# 87 CPI-SS0703338F5   Endo_C05_CXCL12|CAF_NTRK2 0      4.143 LGALS9_CD44
#    partner_a     partner_b     gene_a   gene_b secreted ⋯ cluster_b
# 1  simple:Q9UM47 simple:Q9Y219 NOTCH3   JAG2   FALSE    ⋯ Endo_C05_CXCL12
# 2  simple:P46531 simple:P48745 NOTCH1   NOV     TRUE    ⋯ Endo_C05_CXCL12
# 3  simple:P46531 simple:Q9Y219 NOTCH1   JAG2   FALSE    ⋯ Endo_C05_CXCL12
# 4  simple:P09619 simple:Q9GZP0 PDGFRB   PDGFD   TRUE    ⋯ Endo_C05_CXCL12
# 5  simple:P46531 simple:Q9NR61 NOTCH1   DLL4   FALSE    ⋯ Endo_C05_CXCL12
# 6  simple:P46531 simple:P78504 NOTCH1   JAG1   FALSE    ⋯ Endo_C05_CXCL12
# 7  simple:P30530 simple:Q14393 AXL      GAS6    TRUE    ⋯ Endo_C05_CXCL12
# 8  simple:P15529 simple:P78504 CD46     JAG1   FALSE    ⋯ Endo_C05_CXCL12
# 9  simple:HLAC   simple:Q92520 HLA-C    FAM3C   TRUE    ⋯ Endo_C05_CXCL12
# 10 simple:P19438 simple:P28799 TNFRSF1A GRN     TRUE    ⋯ Endo_C05_CXCL12
# 11 simple:P20333 simple:P28799 TNFRSF1B GRN     TRUE    ⋯ Endo_C05_CXCL12
# 12 simple:Q9UM47 simple:Q9Y219 NOTCH3   JAG2   FALSE    ⋯ Endo_C05_CXCL12
# 13 simple:P46531 simple:P48745 NOTCH1   NOV     TRUE    ⋯ Endo_C05_CXCL12
# 14 simple:P46531 simple:Q9Y219 NOTCH1   JAG2   FALSE    ⋯ Endo_C05_CXCL12
# 15 simple:P09619 simple:Q9GZP0 PDGFRB   PDGFD   TRUE    ⋯ Endo_C05_CXCL12
# 16 simple:P46531 simple:Q9NR61 NOTCH1   DLL4   FALSE    ⋯ Endo_C05_CXCL12
# 17 simple:Q04721 simple:Q9Y219 NOTCH2   JAG2   FALSE    ⋯ Endo_C05_CXCL12
# 18 simple:P46531 simple:P78504 NOTCH1   JAG1   FALSE    ⋯ Endo_C05_CXCL12
# 19 simple:Q04721 simple:Q9NR61 NOTCH2   DLL4   FALSE    ⋯ Endo_C05_CXCL12
# 20 simple:P30530 simple:Q14393 AXL      GAS6    TRUE    ⋯ Endo_C05_CXCL12
# 21 simple:P00533 simple:P28799 EGFR     GRN     TRUE    ⋯ Endo_C05_CXCL12
# 22 simple:P00533 simple:P53621 EGFR     COPA    TRUE    ⋯ Endo_C05_CXCL12
# 23 simple:P00533 simple:P14174 EGFR     MIF     TRUE    ⋯ Endo_C05_CXCL12
# 24 simple:P15529 simple:P78504 CD46     JAG1   FALSE    ⋯ Endo_C05_CXCL12
# 25 simple:P19438 simple:P28799 TNFRSF1A GRN     TRUE    ⋯ Endo_C05_CXCL12
# 26 simple:Q9UM47 simple:Q9Y219 NOTCH3   JAG2   FALSE    ⋯ Endo_C05_CXCL12
# 27 simple:P25106 simple:P48061 ACKR3    CXCL12  TRUE    ⋯ Endo_C05_CXCL12
# 28 simple:P09619 simple:Q9GZP0 PDGFRB   PDGFD   TRUE    ⋯ Endo_C05_CXCL12
# 29 simple:Q04721 simple:Q9Y219 NOTCH2   JAG2   FALSE    ⋯ Endo_C05_CXCL12
# 30 simple:Q04721 simple:Q9NR61 NOTCH2   DLL4   FALSE    ⋯ Endo_C05_CXCL12
# ⋮  ⋮             ⋮             ⋮        ⋮      ⋮        ⋱ ⋮
# 58 simple:P01127 simple:P09619 PDGFB    PDGFRB  TRUE    ⋯ CAF_LUM
# 59 simple:P20827 simple:P29320 EFNA1    EPHA3   TRUE    ⋯ CAF_LUM
# 60 simple:P09038 simple:P16070 FGF2     CD44    TRUE    ⋯ CAF_LUM
# 61 simple:O00182 simple:Q9UBG0 LGALS9   MRC2    TRUE    ⋯ CAF_LUM
# 62 simple:P01127 simple:Q07954 PDGFB    LRP1    TRUE    ⋯ CAF_LUM
# 63 simple:P07225 simple:P30530 PROS1    AXL     TRUE    ⋯ CAF_LUM
# 64 simple:P21741 simple:Q07954 MDK      LRP1    TRUE    ⋯ CAF_LUM
# 65 simple:O00182 simple:Q14118 LGALS9   DAG1    TRUE    ⋯ CAF_LUM
# 66 simple:O00182 simple:Q15262 LGALS9   PTPRK   TRUE    ⋯ CAF_LUM
# 67 simple:P78504 simple:Q04721 JAG1     NOTCH2 FALSE    ⋯ CAF_LUM
# 68 simple:P20827 simple:P21709 EFNA1    EPHA1   TRUE    ⋯ CAF_LUM
# 69 simple:O00182 simple:Q07954 LGALS9   LRP1    TRUE    ⋯ CAF_LUM
# 70 simple:O00182 simple:Q15758 LGALS9   SLC1A5  TRUE    ⋯ CAF_LUM
# 71 simple:O00182 simple:Q08722 LGALS9   CD47    TRUE    ⋯ CAF_LUM
# 72 simple:O00182 simple:P16070 LGALS9   CD44    TRUE    ⋯ CAF_LUM
# 73 simple:Q96QR1 simple:Q9UM47 SCGB3A1  NOTCH3  TRUE    ⋯ CAF_NTRK2
# 74 simple:Q9NR61 simple:Q9UM47 DLL4     NOTCH3 FALSE    ⋯ CAF_NTRK2
# 75 simple:P78504 simple:Q9UM47 JAG1     NOTCH3 FALSE    ⋯ CAF_NTRK2
# 76 simple:P01127 simple:P09619 PDGFB    PDGFRB  TRUE    ⋯ CAF_NTRK2
# 77 simple:P20827 simple:P29320 EFNA1    EPHA3   TRUE    ⋯ CAF_NTRK2
# 78 simple:P09038 simple:P16070 FGF2     CD44    TRUE    ⋯ CAF_NTRK2
# 79 simple:P07225 simple:P30530 PROS1    AXL     TRUE    ⋯ CAF_NTRK2
# 80 simple:O00182 simple:Q14118 LGALS9   DAG1    TRUE    ⋯ CAF_NTRK2
# 81 simple:O00182 simple:Q15262 LGALS9   PTPRK   TRUE    ⋯ CAF_NTRK2
# 82 simple:P78504 simple:Q04721 JAG1     NOTCH2 FALSE    ⋯ CAF_NTRK2
# 83 simple:P20827 simple:P21709 EFNA1    EPHA1   TRUE    ⋯ CAF_NTRK2
# 84 simple:P53621 simple:Q99523 COPA     SORT1   TRUE    ⋯ CAF_NTRK2
# 85 simple:P28799 simple:Q99523 GRN      SORT1   TRUE    ⋯ CAF_NTRK2
# 86 simple:O00182 simple:Q08722 LGALS9   CD47    TRUE    ⋯ CAF_NTRK2
# 87 simple:O00182 simple:P16070 LGALS9   CD44    TRUE    ⋯ CAF_NTRK2
#    sending         ligand  receiver  receptor fractionExprLigand meanExprLigand
# 1  Endo_C05_CXCL12 JAG2    CAF_CD36  NOTCH3   0.7741935          4.011289
# 2  Endo_C05_CXCL12 NOV     CAF_CD36  NOTCH1   0.6543779          4.859402
# 3  Endo_C05_CXCL12 JAG2    CAF_CD36  NOTCH1   0.7741935          4.011289
# 4  Endo_C05_CXCL12 PDGFD   CAF_CD36  PDGFRB   0.7096774          4.073064
# 5  Endo_C05_CXCL12 DLL4    CAF_CD36  NOTCH1   0.9447005          7.156052
# 6  Endo_C05_CXCL12 JAG1    CAF_CD36  NOTCH1   0.9400922          6.176740
# 7  Endo_C05_CXCL12 GAS6    CAF_CD36  AXL      0.8571429          4.709506
# 8  Endo_C05_CXCL12 JAG1    CAF_CD36  CD46     0.9400922          6.176740
# 9  Endo_C05_CXCL12 FAM3C   CAF_CD36  HLA-C    0.5207373          2.601382
# 10 Endo_C05_CXCL12 GRN     CAF_CD36  TNFRSF1A 0.9815668          8.439660
# 11 Endo_C05_CXCL12 GRN     CAF_CD36  TNFRSF1B 0.9815668          8.439660
# 12 Endo_C05_CXCL12 JAG2    CAF_LUM   NOTCH3   0.7741935          4.011289
# 13 Endo_C05_CXCL12 NOV     CAF_LUM   NOTCH1   0.6543779          4.859402
# 14 Endo_C05_CXCL12 JAG2    CAF_LUM   NOTCH1   0.7741935          4.011289
# 15 Endo_C05_CXCL12 PDGFD   CAF_LUM   PDGFRB   0.7096774          4.073064
# 16 Endo_C05_CXCL12 DLL4    CAF_LUM   NOTCH1   0.9447005          7.156052
# 17 Endo_C05_CXCL12 JAG2    CAF_LUM   NOTCH2   0.7741935          4.011289
# 18 Endo_C05_CXCL12 JAG1    CAF_LUM   NOTCH1   0.9400922          6.176740
# 19 Endo_C05_CXCL12 DLL4    CAF_LUM   NOTCH2   0.9447005          7.156052
# 20 Endo_C05_CXCL12 GAS6    CAF_LUM   AXL      0.8571429          4.709506
# 21 Endo_C05_CXCL12 GRN     CAF_LUM   EGFR     0.9815668          8.439660
# 22 Endo_C05_CXCL12 COPA    CAF_LUM   EGFR     0.8709677          4.088205
# 23 Endo_C05_CXCL12 MIF     CAF_LUM   EGFR     0.9032258          5.285597
# 24 Endo_C05_CXCL12 JAG1    CAF_LUM   CD46     0.9400922          6.176740
# 25 Endo_C05_CXCL12 GRN     CAF_LUM   TNFRSF1A 0.9815668          8.439660
# 26 Endo_C05_CXCL12 JAG2    CAF_NTRK2 NOTCH3   0.7741935          4.011289
# 27 Endo_C05_CXCL12 CXCL12  CAF_NTRK2 ACKR3    0.8294931          5.465104
# 28 Endo_C05_CXCL12 PDGFD   CAF_NTRK2 PDGFRB   0.7096774          4.073064
# 29 Endo_C05_CXCL12 JAG2    CAF_NTRK2 NOTCH2   0.7741935          4.011289
# 30 Endo_C05_CXCL12 DLL4    CAF_NTRK2 NOTCH2   0.9447005          7.156052
# ⋮  ⋮               ⋮       ⋮         ⋮        ⋮                  ⋮
# 58 Endo_C05_CXCL12 PDGFB   CAF_LUM   PDGFRB   0.5622120          3.116487
# 59 Endo_C05_CXCL12 EFNA1   CAF_LUM   EPHA3    0.9539171          8.388665
# 60 Endo_C05_CXCL12 FGF2    CAF_LUM   CD44     0.5207373          2.207440
# 61 Endo_C05_CXCL12 LGALS9  CAF_LUM   MRC2     0.7603687          4.270178
# 62 Endo_C05_CXCL12 PDGFB   CAF_LUM   LRP1     0.5622120          3.116487
# 63 Endo_C05_CXCL12 PROS1   CAF_LUM   AXL      0.6635945          3.041841
# 64 Endo_C05_CXCL12 MDK     CAF_LUM   LRP1     0.8156682          5.673349
# 65 Endo_C05_CXCL12 LGALS9  CAF_LUM   DAG1     0.7603687          4.270178
# 66 Endo_C05_CXCL12 LGALS9  CAF_LUM   PTPRK    0.7603687          4.270178
# 67 Endo_C05_CXCL12 JAG1    CAF_LUM   NOTCH2   0.9400922          6.176740
# 68 Endo_C05_CXCL12 EFNA1   CAF_LUM   EPHA1    0.9539171          8.388665
# 69 Endo_C05_CXCL12 LGALS9  CAF_LUM   LRP1     0.7603687          4.270178
# 70 Endo_C05_CXCL12 LGALS9  CAF_LUM   SLC1A5   0.7603687          4.270178
# 71 Endo_C05_CXCL12 LGALS9  CAF_LUM   CD47     0.7603687          4.270178
# 72 Endo_C05_CXCL12 LGALS9  CAF_LUM   CD44     0.7603687          4.270178
# 73 Endo_C05_CXCL12 SCGB3A1 CAF_NTRK2 NOTCH3   0.3917051          2.287317
# 74 Endo_C05_CXCL12 DLL4    CAF_NTRK2 NOTCH3   0.9447005          7.156052
# 75 Endo_C05_CXCL12 JAG1    CAF_NTRK2 NOTCH3   0.9400922          6.176740
# 76 Endo_C05_CXCL12 PDGFB   CAF_NTRK2 PDGFRB   0.5622120          3.116487
# 77 Endo_C05_CXCL12 EFNA1   CAF_NTRK2 EPHA3    0.9539171          8.388665
# 78 Endo_C05_CXCL12 FGF2    CAF_NTRK2 CD44     0.5207373          2.207440
# 79 Endo_C05_CXCL12 PROS1   CAF_NTRK2 AXL      0.6635945          3.041841
# 80 Endo_C05_CXCL12 LGALS9  CAF_NTRK2 DAG1     0.7603687          4.270178
# 81 Endo_C05_CXCL12 LGALS9  CAF_NTRK2 PTPRK    0.7603687          4.270178
# 82 Endo_C05_CXCL12 JAG1    CAF_NTRK2 NOTCH2   0.9400922          6.176740
# 83 Endo_C05_CXCL12 EFNA1   CAF_NTRK2 EPHA1    0.9539171          8.388665
# 84 Endo_C05_CXCL12 COPA    CAF_NTRK2 SORT1    0.8709677          4.088205
# 85 Endo_C05_CXCL12 GRN     CAF_NTRK2 SORT1    0.9815668          8.439660
# 86 Endo_C05_CXCL12 LGALS9  CAF_NTRK2 CD47     0.7603687          4.270178
# 87 Endo_C05_CXCL12 LGALS9  CAF_NTRK2 CD44     0.7603687          4.270178
#    fractionExprReceptor meanExprReceptor LR
# 1  0.9672131             6.343642        JAG2-NOTCH3
# 2  0.6182670             2.406864        NOV-NOTCH1
# 3  0.6182670             2.406864        JAG2-NOTCH1
# 4  0.9882904             8.190654        PDGFD-PDGFRB
# 5  0.6182670             2.406864        DLL4-NOTCH1
# 6  0.6182670             2.406864        JAG1-NOTCH1
# 7  0.9601874             7.459496        GAS6-AXL
# 8  0.8548009             4.186729        JAG1-CD46
# 9  1.0000000            10.704546        FAM3C-HLA-C
# 10 0.8711944             5.566997        GRN-TNFRSF1A
# 11 0.4496487             2.418072        GRN-TNFRSF1B
# 12 0.7457627             3.403754        JAG2-NOTCH3
# 13 0.6101695             2.151661        NOV-NOTCH1
# 14 0.6101695             2.151661        JAG2-NOTCH1
# 15 0.9322034             7.175105        PDGFD-PDGFRB
# 16 0.6101695             2.151661        DLL4-NOTCH1
# 17 0.8813559             3.512663        JAG2-NOTCH2
# 18 0.6101695             2.151661        JAG1-NOTCH1
# 19 0.8813559             3.512663        DLL4-NOTCH2
# 20 0.8983051             5.430506        GAS6-AXL
# 21 0.7796610             2.654463        GRN-EGFR
# 22 0.7796610             2.654463        COPA-EGFR
# 23 0.7796610             2.654463        MIF-EGFR
# 24 0.8474576             3.765666        JAG1-CD46
# 25 0.9322034             6.291853        GRN-TNFRSF1A
# 26 0.9877301             6.207801        JAG2-NOTCH3
# 27 0.5582822             3.094825        CXCL12-ACKR3
# 28 0.9938650             7.292726        PDGFD-PDGFRB
# 29 0.7484663             2.350002        JAG2-NOTCH2
# 30 0.7484663             2.350002        DLL4-NOTCH2
# ⋮  ⋮                    ⋮                ⋮
# 58 0.9322034            7.175105         PDGFB-PDGFRB
# 59 0.8135593            5.041494         EFNA1-EPHA3
# 60 0.6949153            3.123899         FGF2-CD44
# 61 0.8644068            3.879589         LGALS9-MRC2
# 62 0.9830508            4.794811         PDGFB-LRP1
# 63 0.8983051            5.430506         PROS1-AXL
# 64 0.9830508            4.794811         MDK-LRP1
# 65 0.6101695            2.145277         LGALS9-DAG1
# 66 0.6440678            2.380081         LGALS9-PTPRK
# 67 0.8813559            3.512663         JAG1-NOTCH2
# 68 0.7627119            2.624144         EFNA1-EPHA1
# 69 0.9830508            4.794811         LGALS9-LRP1
# 70 0.4576271            2.293053         LGALS9-SLC1A5
# 71 0.8135593            3.907402         LGALS9-CD47
# 72 0.6949153            3.123899         LGALS9-CD44
# 73 0.9877301            6.207801         SCGB3A1-NOTCH3
# 74 0.9877301            6.207801         DLL4-NOTCH3
# 75 0.9877301            6.207801         JAG1-NOTCH3
# 76 0.9938650            7.292726         PDGFB-PDGFRB
# 77 0.5398773            2.341166         EFNA1-EPHA3
# 78 0.6196319            2.746096         FGF2-CD44
# 79 0.9141104            7.376112         PROS1-AXL
# 80 0.6809816            2.767875         LGALS9-DAG1
# 81 0.6687117            3.008242         LGALS9-PTPRK
# 82 0.7484663            2.350002         JAG1-NOTCH2
# 83 0.8098160            3.253978         EFNA1-EPHA1
# 84 0.8282209            4.735139         COPA-SORT1
# 85 0.8282209            4.735139         GRN-SORT1
# 86 0.6503067            2.737236         LGALS9-CD47
# 87 0.6196319            2.746096         LGALS9-CD44

# %%
topInteract_CAF2Mac <- topInteract_filtered %>% 
   mutate(LR = paste0(ligand, "-", receptor)) %>%
   filter(grepl("CAF", sending )) %>%  
   filter(grepl("^Mphi", receiver))

# %%
topInteract_CAF2tumor <- topInteract_filtered %>% 
   mutate(LR = paste0(ligand, "-", receptor)) %>%
   filter(grepl("CAF", sending )) %>%  
   filter(grepl("^HCC|^Hepa", receiver))

# %%
topInteract_tumor2CAF <- topInteract_clean %>% 
   mutate(LR = paste0(ligand, "-", receptor)) %>%
   filter(grepl("^HCC|^Hepa", sending )) %>%  
   filter(grepl("CAF", receiver))

# %%
topInteract_CAF2Mac <- topInteract_filtered %>% 
   mutate(LR = paste0(ligand, "-", receptor)) %>%
   filter(grepl("CAF", sending )) %>%  
   filter(grepl("^Mphi", receiver))

# %%
table(topInteract_clean$sending)
# Out:
#             B.Cell           CAF_CD36            CAF_LUM          CAF_NTRK2
#                570               1058               1477               1051
#       CD4.C3.ANXA1        CD4.C4.IL7R        CD4.C5.TCF7      CD4.C6.CXCL13
#                406                552                618                669
#       CD4.C7.FOXP3    CD4.CD8.C1.CCR7   CD4.CD8.C2.MKI67        CD8.C3.IL7R
#                443                354               1091                309
#      CD8.C4.CX3CR1        CD8.C5.SELL        CD8.C6.GZMK       CD8.C7.KLRD1
#                314                347                551                543
#       CD8.C8.PDCD1     CD8.C9.SLC4A10 cHCC_ICC_D20171229         DC.C1.CD1C
#                771                571               1240               1159
#       DC.C2.FCER1A       DC.C3.CLEC9A        DC.C4.LAMP3    Endo_C01_CLEC4G
#               1071               1102                971                999
#     Endo_C02_ACKR1     Endo_C03_GABRD      Endo_C04_FMO2    Endo_C05_CXCL12
#               1605               1613               1341               1532
#      HCC_Malignant        Hepatocytes               hLPS      ICC_D20171215
#               1039                459               1085               1378
#               ILCs       Mast.C1.IL7R       Mast.C2.CPA3       Mono.C1.CD14
#                700                739                936                758
#     Mono.C2.FCGR3A      Mphi.C1.THBS1       Mphi.C2.C1QA       Mphi.C5.VCAN
#               1030                998               1342                900
#      Mphi.C6.MARCO       NK.C1.FCGR3A         NK.C2.SELL         NK.C3.IFNG
#               1072                424                485                679
#         NK.C5.CD69         NK.C6.IL7R        NK.C7.CD160        NK.C9.MKI67
#                543                508                685                675
#      Plasma.B.Cell
#                607

# %%
topInteract_CAF2Mac  %>% 
    group_by(sending, receiver) %>% 
    summarise(count = n())
# Out:
# `summarise()` has grouped output by 'sending'. You can override using the `.groups` argument.
#    sending   receiver      count
# 1  CAF_CD36  Mphi-C1-THBS1 22
# 2  CAF_CD36  Mphi-C2-C1QA  31
# 3  CAF_CD36  Mphi-C5-VCAN  22
# 4  CAF_CD36  Mphi-C6-MARCO 29
# 5  CAF_LUM   Mphi-C1-THBS1 27
# 6  CAF_LUM   Mphi-C2-C1QA  38
# 7  CAF_LUM   Mphi-C5-VCAN  29
# 8  CAF_LUM   Mphi-C6-MARCO 36
# 9  CAF_NTRK2 Mphi-C1-THBS1 19
# 10 CAF_NTRK2 Mphi-C2-C1QA  28
# 11 CAF_NTRK2 Mphi-C5-VCAN  19
# 12 CAF_NTRK2 Mphi-C6-MARCO 27

# %%
topInteract_tumor2CAF %>% filter(grepl("CD36", receiver)) %>% 
    group_by(sending, receiver) %>% 
    summarise(count = n())
# Out:
# `summarise()` has grouped output by 'sending'. You can override using the `.groups` argument.
#   sending       receiver count
# 1 HCC_Malignant CAF_CD36 31
# 2 Hepatocytes   CAF_CD36  9

# %%
topInt

# %%
options(repr.plot.width = 6, repr.plot.height = 8, repr.plot.res = 300)
  my_palette <- colorRampPalette(c("black", "blue", "yellow", "red"), alpha=TRUE)(n=399)
topInteract_tumor2CAF %>% 
   mutate(pvalue = case_when(pvalue == 0 ~ 0.009,
                            TRUE ~ pvalue)) %>%
    ggplot(aes(y = LR, x = receiver)) +
        geom_point(aes(size = -log10(pvalue),  color = mean)) +
        scale_color_gradientn('Log2 mean (Molecule 1, Molecule 2)', colors=my_palette) +
        facet_grid(. ~ sending) +
       theme_bw() +
  theme(panel.grid.minor = element_blank(),
        panel.grid.major = element_blank(),
        axis.text=element_text(size=14, colour = "black"),
        axis.text.x = element_text(angle = 90, hjust = 1),
        axis.text.y = element_text(size=12, colour = "black"),
        axis.title=element_blank(),
        panel.border = element_rect(size = 0.7, linetype = "solid", colour = "black"))
# Out:
# plot without title

# %%
topInteract_CAF2tumor %>% filter(receptor == 'MET')
# Out:
# Warning message in cbind(parts$left, ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
#      id_cp_interaction cluster_pair pvalue mean interacting_pair partner_a
#      partner_b gene_a gene_b secreted ⋯ cluster_b sending ligand receiver
#      receptor fractionExprLigand meanExprLigand fractionExprReceptor
#      meanExprReceptor LR

# %%
topInteract_CAF2tumor %>% 
   mutate(pvalue = case_when(pvalue == 0 ~ 0.009,
                            TRUE ~ pvalue)) %>%
    #filter(secreted) %>% 
    filter(annotation_strategy != "I2D") %>%
    group_by(LR,ligand,receptor,  receiver) %>%
    summarise(count = n()) %>%
    tidyr::pivot_wider(id_cols = c('LR', 'ligand', 'receptor') , names_from = receiver, values_from = count,values_fill = 0)  %>%
    .$ligand %>% unique()
    #tidyr::separate(LR, into = c("Ligand", "Receptor"), sep = "-") %>%
    #openxlsx::write.xlsx("test.xlsx")
# Out:
# `summarise()` has grouped output by 'LR', 'ligand', 'receptor'. You can override using the `.groups` argument.
#  [1] "AGT"      "COPA"     "CXCL12"   "FAM3C"    "GRN"      "HGF"
#  [7] "IGF2"     "JAG1"     "MDK"      "MIF"      "OGN"      "PGF"
# [13] "PTN"      "TNFSF12"  "TNFSF13B"

# %%
topInteract_tumor2CAF %>% 
   mutate(pvalue = case_when(pvalue == 0 ~ 0.009,
                            TRUE ~ pvalue)) %>%
    filter(secreted) %>% 
    filter(annotation_strategy != "I2D") %>%
    group_by(LR, sending) %>%
    summarise(count = n()) %>%
    tidyr::pivot_wider(id_cols = LR , names_from = sending, values_from = count,values_fill = 0) %>%
    filter(HCC_Malignant == 3 & Hepatocytes == 0)
# Out:
# Error in mutate(., pvalue = case_when(pvalue == 0 ~ 0.009, TRUE ~ pvalue)): object 'topInteract_tumor2CAF' not found
# Traceback:
#
# 1. topInteract_tumor2CAF %>% mutate(pvalue = case_when(pvalue ==
#  .     0 ~ 0.009, TRUE ~ pvalue)) %>% filter(secreted) %>% filter(annotation_strategy !=
#  .     "I2D") %>% group_by(LR, sending) %>% summarise(count = n()) %>%
#  .     tidyr::pivot_wider(id_cols = LR, names_from = sending, values_from = count,
#  .         values_fill = 0) %>% filter(HCC_Malignant == 3 & Hepatocytes ==
#  .     0)
# 2. filter(., HCC_Malignant == 3 & Hepatocytes == 0)
# 3. tidyr::pivot_wider(., id_cols = LR, names_from = sending, values_from = count,
#  .     values_fill = 0)
# 4. summarise(., count = n())
# 5. group_by(., LR, sending)
# 6. filter(., annotation_strategy != "I2D")
# 7. filter(., secreted)
# 8. mutate(., pvalue = case_when(pvalue == 0 ~ 0.009, TRUE ~ pvalue))

# %% [markdown]
# ## CAF to Tumor

# %%
?guide_colorbar
# Out:
# guide_colourbar            package:ggplot2             R Documentation
#
# e
#
# n:
#
#      Colour bar guide shows continuous colour scales mapped onto
#      values. Colour bar is available with ‘scale_fill’ and
#      ‘scale_colour’. For more information, see the inspiration for this
#      function: Matlab's colorbar function.
#
# e:
#
#      guide_colourbar(
#        title = waiver(),
#        title.position = NULL,
#        title.theme = NULL,
#        title.hjust = NULL,
#        title.vjust = NULL,
#        label = TRUE,
#        label.position = NULL,
#        label.theme = NULL,
#        label.hjust = NULL,
#        label.vjust = NULL,
#        barwidth = NULL,
#        barheight = NULL,
#        nbin = 300,
#        raster = TRUE,
#        frame.colour = NULL,
#        frame.linewidth = 0.5,
#        frame.linetype = 1,
#        ticks = TRUE,
#        ticks.colour = "white",
#        ticks.linewidth = 0.5,
#        draw.ulim = TRUE,
#        draw.llim = TRUE,
#        direction = NULL,
#        default.unit = "line",
#        reverse = FALSE,
#        order = 0,
#        available_aes = c("colour", "color", "fill"),
#        ...
#      )
#
#      guide_colorbar(
#        title = waiver(),
#        title.position = NULL,
#        title.theme = NULL,
#        title.hjust = NULL,
#        title.vjust = NULL,
#        label = TRUE,
#        label.position = NULL,
#        label.theme = NULL,
#        label.hjust = NULL,
#        label.vjust = NULL,
#        barwidth = NULL,
#        barheight = NULL,
#        nbin = 300,
#        raster = TRUE,
#        frame.colour = NULL,
#        frame.linewidth = 0.5,
#        frame.linetype = 1,
#        ticks = TRUE,
#        ticks.colour = "white",
#        ticks.linewidth = 0.5,
#        draw.ulim = TRUE,
#        draw.llim = TRUE,
#        direction = NULL,
#        default.unit = "line",
#        reverse = FALSE,
#        order = 0,
#        available_aes = c("colour", "color", "fill"),
#        ...
#      )
#
# s:
#
#    title: A character string or expression indicating a title of guide.
#           If ‘NULL’, the title is not shown. By default (‘waiver()’),
#           the name of the scale object or the name specified in
#           ‘labs()’ is used for the title.
#
# title.position: A character string indicating the position of a title.
#           One of "top" (default for a vertical guide), "bottom", "left"
#           (default for a horizontal guide), or "right."
#
# title.theme: A theme object for rendering the title text. Usually the
#           object of ‘element_text()’ is expected. By default, the theme
#           is specified by ‘legend.title’ in ‘theme()’ or theme.
#
# title.hjust: A number specifying horizontal justification of the title
#           text.
#
# title.vjust: A number specifying vertical justification of the title
#           text.
#
#    label: logical. If ‘TRUE’ then the labels are drawn. If ‘FALSE’ then
#           the labels are invisible.
#
# label.position: A character string indicating the position of a label.
#           One of "top", "bottom" (default for horizontal guide),
#           "left", or "right" (default for vertical guide).
#
# label.theme: A theme object for rendering the label text. Usually the
#           object of ‘element_text()’ is expected. By default, the theme
#           is specified by ‘legend.text’ in ‘theme()’.
#
# label.hjust: A numeric specifying horizontal justification of the label
#           text.
#
# label.vjust: A numeric specifying vertical justification of the label
#           text.
#
# barwidth: A numeric or a ‘grid::unit()’ object specifying the width of
#           the colourbar. Default value is ‘legend.key.width’ or
#           ‘legend.key.size’ in ‘theme()’ or theme.
#
# barheight: A numeric or a ‘grid::unit()’ object specifying the height
#           of the colourbar. Default value is ‘legend.key.height’ or
#           ‘legend.key.size’ in ‘theme()’ or theme.
#
#     nbin: A numeric specifying the number of bins for drawing the
#           colourbar. A smoother colourbar results from a larger value.
#
#   raster: A logical. If ‘TRUE’ then the colourbar is rendered as a
#           raster object. If ‘FALSE’ then the colourbar is rendered as a
#           set of rectangles. Note that not all graphics devices are
#           capable of rendering raster image.
#
# frame.colour: A string specifying the colour of the frame drawn around
#           the bar. If ‘NULL’ (the default), no frame is drawn.
#
# frame.linewidth: A numeric specifying the width of the frame drawn
#           around the bar.
#
# frame.linetype: A numeric specifying the linetype of the frame drawn
#           around the bar.
#
#    ticks: A logical specifying if tick marks on the colourbar should be
#           visible.
#
# ticks.colour: A string specifying the colour of the tick marks.
#
# ticks.linewidth: A numeric specifying the width of the tick marks.
#
# draw.ulim: A logical specifying if the upper limit tick marks should be
#           visible.
#
# draw.llim: A logical specifying if the lower limit tick marks should be
#           visible.
#
# direction: A character string indicating the direction of the guide.
#           One of "horizontal" or "vertical."
#
# default.unit: A character string indicating ‘grid::unit()’ for
#           ‘barwidth’ and ‘barheight’.
#
#  reverse: logical. If ‘TRUE’ the colourbar is reversed. By default, the
#           highest value is on the top and the lowest value is on the
#           bottom
#
#    order: positive integer less than 99 that specifies the order of
#           this guide among multiple guides. This controls the order in
#           which multiple guides are displayed, not the contents of the
#           guide itself. If 0 (default), the order is determined by a
#           secret algorithm.
#
# available_aes: A vector of character strings listing the aesthetics for
#           which a colourbar can be drawn.
#
#      ...: ignored.
#
# s:
#
#      Guides can be specified in each scale_* or in ‘guides()’.
#      ‘guide="legend"’ in scale_* is syntactic sugar for
#      ‘guide=guide_legend()’ (e.g. ‘scale_colour_manual(guide =
#      "legend")’). As for how to specify the guide for each scale in
#      more detail, see ‘guides()’.
#
# e:
#
#      A guide object
#
# o:
#
#      Other guides: ‘guide_bins()’, ‘guide_coloursteps()’,
#      ‘guide_legend()’, ‘guides()’
#
# s:
#
#      df <- expand.grid(X1 = 1:10, X2 = 1:10)
#      df$value <- df$X1 * df$X2
#
#      p1 <- ggplot(df, aes(X1, X2)) + geom_tile(aes(fill = value))
#      p2 <- p1 + geom_point(aes(size = value))
#
#      # Basic form
#      p1 + scale_fill_continuous(guide = "colourbar")
#      p1 + scale_fill_continuous(guide = guide_colourbar())
#      p1 + guides(fill = guide_colourbar())
#
#      # Control styles
#
#      # bar size
#      p1 + guides(fill = guide_colourbar(barwidth = 0.5, barheight = 10))
#
#      # no label
#      p1 + guides(fill = guide_colourbar(label = FALSE))
#
#      # no tick marks
#      p1 + guides(fill = guide_colourbar(ticks = FALSE))
#
#      # label position
#      p1 + guides(fill = guide_colourbar(label.position = "left"))
#
#      # label theme
#      p1 + guides(fill = guide_colourbar(label.theme = element_text(colour = "blue", angle = 0)))
#
#      # small number of bins
#      p1 + guides(fill = guide_colourbar(nbin = 3))
#
#      # large number of bins
#      p1 + guides(fill = guide_colourbar(nbin = 100))
#
#      # make top- and bottom-most ticks invisible
#      p1 + scale_fill_continuous(limits = c(0,20), breaks = c(0, 5, 10, 15, 20),
#       guide = guide_colourbar(nbin=100, draw.ulim = FALSE, draw.llim = FALSE))
#
#      # guides can be controlled independently
#      p2 +
#        scale_fill_continuous(guide = "colourbar") +
#        scale_size(guide = "legend")
#      p2 + guides(fill = "colourbar", size = "legend")
#
#      p2 +
#        scale_fill_continuous(guide = guide_colourbar(direction = "horizontal")) +
#        scale_size(guide = guide_legend(direction = "vertical"))

# %%
options(repr.plot.width = 6, repr.plot.height = 6, repr.plot.res = 300)
  my_palette <- colorRampPalette(c("black", "blue", "yellow", "red"), alpha=TRUE)(n=399)
topInteract_CAF2tumor %>% 
   mutate(pvalue = case_when(pvalue == 0 ~ 0.009,
                            TRUE ~ pvalue)) %>%
    filter(secreted)  %>%
    ggplot(aes(y = LR, x = sending)) +
        geom_point(aes(size = -log10(pvalue),  fill = mean), shape = 21, color = 'black', stroke = .1 ) +
        scale_fill_gradientn('Log2 mean \n(Molecule 1, Molecule 2)', colors=my_palette, 
                             guide = guide_colorbar(title.theme = element_text(size = 6), title.position = "top", direction = "vertical" )) +
        facet_grid(. ~ receiver) +
        guides(size = guide_none()) + 
        coord_flip() + 
       theme_bw(base_size = 12) +
  theme(legend.position = 'right', panel.grid.minor = element_blank(),
        panel.grid.major = element_blank(),
        axis.text=element_text(size=14, colour = "black"),
        axis.text.x = element_text(angle = 90, hjust = 1),
        axis.text.y = element_text(size=12, colour = "black"),
        axis.title=element_blank(),
        panel.border = element_rect(size = 0.7, linetype = "solid", colour = "black"))
# Out:
# plot without title

# %%
openxlsx::write.xlsx(topInteract, file = "./out/D20171220_tumor2all/topInteract.xlsx")
