# %%
suppressPackageStartupMessages({
    library(scater)
    library(Seurat)
    library(ComplexHeatmap)
    library(logger)
    library(infercnv)
})

# %% [markdown]
# # Read inferCNV

# %%
infercnv_obj <- readRDS("./out_inferCNV/hepatoctyes_sd1.75_NULL_subclusters/run.final.infercnv_obj")

# %% [markdown]
# # Meidan Filtering

# %%
log_info("Applying Median filtering...")
infercnv_obj_medianfiltered = infercnv::apply_median_filtering(infercnv_obj = infercnv_obj, on_observations = TRUE)
log_info("Done filtering...")
# Out:
# INFO [2020-09-23 00:56:29] Applying Median filtering...
# INFO [2020-09-23 01:01:26] Done filtering...

# %%
all(infercnv_obj_medianfiltered@expr.data == infercnv_obj@expr.data)
# Out:
# [1] FALSE

# %%
mt_obs <- infercnv_obj_medianfiltered@expr.data

# %% [markdown]
# # Read Gene order

# %%
gene_order <- infercnv_obj_medianfiltered@gene_order

# %% [markdown]
# # Read SCE

# %%
sce <- readRDS("../../data/expression/sce/sce_Smartseq2_scHCC-CD45_featureCounts_qc_clustered_hepatocytes.rds")
sce <- sce[, colnames(mt_obs)]
coldata <- as.data.frame(colData(sce))
#coldata <- coldata[colnames(mt_obs), ]

# %%
table(sce$donor, sce$tissue)
# Out:
#
#             Normal Tumor TumorCore
#   D20170322      0    31         0
#   D20170327     27   177         0
#   D20170412      0    17         0
#   D20171109      0    14         0
#   D20171220     10   158         0
#   D20180108      0     6        17
#   D20180110      0   102       165

# %%
# Order Patient
coldata$donor <- factor(coldata$donor, levels = c("D20180110", "D20171220", "D20170327", "D20170322", "D20180108", "D20170412", "D20171109"))
# Order tissue then patient
coldata <- coldata[order(coldata$tissue, coldata$donor, coldata$leiden_sub),]

# %%
mt_obs <- mt_obs[, rownames(coldata)]

# %%
# Order gene order
gene_order <- gene_order[rownames(mt_obs),]
gene_order$chr <- factor(gene_order$chr, levels = paste0("chr", 1:22))
gene_order <- gene_order[order(gene_order$chr),]

# %%
cell_info <- coldata[, c("donor", "tissue", "leiden_sub", "Sample"), drop = F]
cell_info$Sample <- ifelse(grepl("Normal", cell_info$Sample), "Normal", cell_info$Sample)

# %%
ha = HeatmapAnnotation(df = cell_info[, "tissue", drop = F], col = list(tissue = c("Tumor" = '#3B4992FF', 'TumorCore'='#EE0000FF', "Normal" = 'grey')))
#mt = mt - rowMeans(mt)
col_fun <- circlize::colorRamp2(c(-0.5, 0, 0.5), c("darkblue", "white", "darkred"))
mt <- t(mt_obs)
mt <- mt - rowMeans(mt)
mt[mt > 1] = 1
mt[mt < -1] = -1

# %%
cell_info$Sample <- factor(cell_info$Sample, levels = c("D20180110_Tumor", "D20180110_TumorCore", "D20170327_Tumor", "D20171220_Tumor", "D20170322_Tumor", "D20170412_Tumor", "D20171109_Tumor",
                                                        "D20180108_Tumor", "D20180108_TumorCore", "Normal"))

# %%
table(cell_info$Sample)
# Out:
#     D20180110_Tumor D20180110_TumorCore     D20170327_Tumor     D20171220_Tumor
#                 102                 165                 177                 158
#     D20170322_Tumor     D20170412_Tumor     D20171109_Tumor     D20180108_Tumor
#                  31                  17                  14                   6
# D20180108_TumorCore              Normal
#                  17                  37

# %%
order_names <- do.call(c, lapply(split(rownames(mt), cell_info$Sample), function(cids) {
        sub <- mt[cids,]
        cl <- hclust(dist(sub), method = 'ward.D2')
        cl$labels[cl$order]
}))

# %%
cell_info <- cell_info[order_names,]
mt <- mt[order_names,]

# %%
ht <- Heatmap(mt, col = col_fun,  name = "Z score", cluster_rows = FALSE, cluster_columns = FALSE, 
              clustering_method_columns = 'ward.D2', show_column_names = F, show_row_names = F,  
              column_split = gene_order$chr, row_split = cell_info$Sample, row_title_rot = 0, column_title_rot = 90, border = TRUE) + 
rowAnnotation(df = cell_info[, "tissue", drop = F], col = list(tissue = c("Tumor" = '#3B4992FF', 'TumorCore'='#EE0000FF', "Normal" = "grey"))) 

pdf("./figures/heatmap_inferCNV_hepatocytes_average_split_donor_ordered_1.75.pdf", width = 24, height = 9)
draw(ht)
dev.off()
# Out:
# `use_raster` is automatically set to TRUE for a matrix with more than
# 2000 columns You can control `use_raster` argument by explicitly
# setting TRUE/FALSE to it.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
# png
#   2

# %% [markdown]
# # Figure 1

# %%
ht <- Heatmap(mt, col = col_fun,  name = "Z score", cluster_rows = FALSE, cluster_columns = FALSE, 
              clustering_method_columns = 'ward.D2', show_column_names = F, show_row_names = F,  
              column_split = gene_order$chr, row_split = cell_info$Sample, row_title_rot = 0, column_title_rot = 90, border = TRUE) + 
rowAnnotation(df = cell_info[, "tissue", drop = F], col = list(tissue = c("Tumor" = '#3B4992FF', 'TumorCore'='#EE0000FF', "Normal" = "grey"))) 

pdf("../05_figures/figures/Figure1D_heatmap_inferCNV_hepatocytes_average_split_donor_ordered_1.75.pdf", width = 24, height = 9)
draw(ht)
dev.off()
# Out:
# `use_raster` is automatically set to TRUE for a matrix with more than
# 2000 columns You can control `use_raster` argument by explicitly
# setting TRUE/FALSE to it.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
# png
#   2

# %% [markdown]
# # D20180110

# %%
mt_obs <- infercnv_obj_medianfiltered@expr.data
sce <- readRDS("../../data/expression/sce/sce_Smartseq2_scHCC-CD45_featureCounts_qc_clustered_hepatocytes.rds")
sce <- sce[, colnames(mt_obs)]
coldata <- as.data.frame(colData(sce))
coldata <- coldata[coldata$donor == "D20180110",]
mt_obs <- mt_obs[, rownames(coldata)]

# %%
cell_info <- coldata[, c("donor", "tissue")]

# %%
library(ComplexHeatmap)
ha = HeatmapAnnotation(df = cell_info)
#mt = mt - rowMeans(mt)
col_fun <- circlize::colorRamp2(c(-0.5, 0, 0.5), c("darkblue", "white", "darkred"))
mt <- t(mt_obs)
mt <- mt - rowMeans(mt)
mt[mt > 1] = 1
mt[mt < -1] = -1
ht <- Heatmap(mt, col = col_fun,  cluster_rows = FALSE, cluster_columns = FALSE, 
              clustering_method_columns = 'ward.D2', show_column_names = F, show_row_names = F,  
              column_split = gene_order$chr, row_split = cell_info$reference, border = TRUE) + 
rowAnnotation(df = cell_info[, "tissue", drop =F],  col = list(tissue = c("Tumor" = '#3B4992FF', 'TumorCore'='#EE0000FF', "Normal" = "grey"))) 

pdf("../05_figures/figures/Figure1E_heatmap_inferCNV_hepatocytes_average_split_donor_ordered_1.75_D0110.pdf", width = 24, height = 4)
draw(ht)
dev.off()
# Out:
# `use_raster` is automatically set to TRUE for a matrix with more than
# 2000 columns You can control `use_raster` argument by explicitly
# setting TRUE/FALSE to it.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
# png
#   2

# %% [markdown]
# # D20180108

# %%
mt_obs <- infercnv_obj_medianfiltered@expr.data
sce <- readRDS("../../data/expression/sce/sce_Smartseq2_scHCC-CD45_featureCounts_qc_clustered_hepatocytes.rds")
sce <- sce[, colnames(mt_obs)]
coldata <- as.data.frame(colData(sce))
coldata <- coldata[coldata$donor == "D20180108",]
mt_obs <- mt_obs[, rownames(coldata)]

# %%
cell_info <- coldata[, c("donor", "tissue")]

# %%
library(ComplexHeatmap)
ha = HeatmapAnnotation(df = cell_info)
#mt = mt - rowMeans(mt)
col_fun <- circlize::colorRamp2(c(-0.5, 0, 0.5), c("darkblue", "white", "darkred"))
mt <- t(mt_obs)
mt <- mt - rowMeans(mt)
mt[mt > 1] = 1
mt[mt < -1] = -1
ht <- Heatmap(mt, col = col_fun,  cluster_rows = FALSE, cluster_columns = FALSE, 
              clustering_method_columns = 'ward.D2', show_column_names = F, show_row_names = F,  
              column_split = gene_order$chr, row_split = cell_info$reference, border = TRUE) + 
rowAnnotation(df = cell_info[, "tissue", drop =F],  col = list(tissue = c("Tumor" = '#3B4992FF', 'TumorCore'='#EE0000FF', "Normal" = "grey"))) 

pdf("../05_figures/figures/Figure1E_heatmap_inferCNV_hepatocytes_average_split_donor_ordered_1.75_D0108.pdf", width = 24, height = 2)
draw(ht)
dev.off()
# Out:
# `use_raster` is automatically set to TRUE for a matrix with more than
# 2000 columns You can control `use_raster` argument by explicitly
# setting TRUE/FALSE to it.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
# png
#   2

# %% [markdown]
# # D20171220

# %%
mt_obs <- infercnv_obj_medianfiltered@expr.data
sce <- readRDS("../../data/expression/sce/sce_Smartseq2_scHCC-CD45_featureCounts_qc_clustered_hepatocytes.rds")
sce <- sce[, colnames(mt_obs)]
coldata <- as.data.frame(colData(sce))
coldata <- coldata[coldata$donor == "D20171220",]
mt_obs <- mt_obs[, rownames(coldata)]

# %%
cell_info <- coldata[, c("donor", "tissue")]

# %%
library(ComplexHeatmap)
ha = HeatmapAnnotation(df = cell_info)
#mt = mt - rowMeans(mt)
col_fun <- circlize::colorRamp2(c(-0.5, 0, 0.5), c("darkblue", "white", "darkred"))
mt <- t(mt_obs)
mt <- mt - rowMeans(mt)
mt[mt > 1] = 1
mt[mt < -1] = -1
ht <- Heatmap(mt, col = col_fun,  cluster_rows = FALSE, cluster_columns = FALSE, 
              clustering_method_columns = 'ward.D2', show_column_names = F, show_row_names = F,  
              column_split = gene_order$chr, row_split = cell_info$reference, border = TRUE) + 
rowAnnotation(df = cell_info[, "tissue", drop =F],  col = list(tissue = c("Tumor" = '#3B4992FF', 'TumorCore'='#EE0000FF', "Normal" = "grey"))) 

pdf("../05_figures/figures/Figure1E_heatmap_inferCNV_hepatocytes_average_split_donor_ordered_1.75_D1220.pdf", width = 24, height = 4)
draw(ht)
dev.off()
# Out:
# `use_raster` is automatically set to TRUE for a matrix with more than
# 2000 columns You can control `use_raster` argument by explicitly
# setting TRUE/FALSE to it.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
# png
#   2

# %% [markdown]
# # D20170327

# %%
mt_obs <- infercnv_obj_medianfiltered@expr.data
sce <- readRDS("../../data/expression/sce/sce_Smartseq2_scHCC-CD45_featureCounts_qc_clustered_hepatocytes.rds")
sce <- sce[, colnames(mt_obs)]
coldata <- as.data.frame(colData(sce))
coldata <- coldata[coldata$donor == "D20170327",]
mt_obs <- mt_obs[, rownames(coldata)]

# %%
cell_info <- coldata[, c("donor", "tissue")]

# %%
library(ComplexHeatmap)
ha = HeatmapAnnotation(df = cell_info)
#mt = mt - rowMeans(mt)
col_fun <- circlize::colorRamp2(c(-0.5, 0, 0.5), c("darkblue", "white", "darkred"))
mt <- t(mt_obs)
mt <- mt - rowMeans(mt)
mt[mt > 1] = 1
mt[mt < -1] = -1
ht <- Heatmap(mt, col = col_fun,  cluster_rows = FALSE, cluster_columns = FALSE, 
              clustering_method_columns = 'ward.D2', show_column_names = F, show_row_names = F,  
              column_split = gene_order$chr, row_split = cell_info$reference, border = TRUE) + 
rowAnnotation(df = cell_info[, "tissue", drop =F],  col = list(tissue = c("Tumor" = '#3B4992FF', 'TumorCore'='#EE0000FF', "Normal" = "grey"))) 

pdf("../05_figures/figures/Figure1E_heatmap_inferCNV_hepatocytes_average_split_donor_ordered_1.75_D0327.pdf", width = 24, height = 4)
draw(ht)
dev.off()
# Out:
# `use_raster` is automatically set to TRUE for a matrix with more than
# 2000 columns You can control `use_raster` argument by explicitly
# setting TRUE/FALSE to it.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
# png
#   2

# %% [markdown]
# # Add HMM features

# %%
mt_obs <- infercnv_obj_medianfiltered@expr.data
sce <- readRDS("../../data/expression/sce/sce_Smartseq2_scHCC-CD45_featureCounts_qc_clustered_hepatocytes.rds")
sce <- sce[, colnames(mt_obs)]
sr <- as.Seurat(sce)
# Out:
# Warning message:
# “Feature names cannot have underscores ('_'), replacing with dashes ('-')”
# Warning message:
# “Feature names cannot have underscores ('_'), replacing with dashes ('-')”

# %%
sr
# Out:
# An object of class Seurat
# 60682 features across 724 samples within 1 assay
# Active assay: RNA (60682 features, 0 variable features)
#  2 dimensional reductions calculated: PCA, UMAP

# %%
sr = infercnv::add_to_seurat(infercnv_output_path="./out_inferCNV/hepatoctyes_sd1.75_NULL_subclusters//",
                                     seurat_obj=sr, # optional
                                     top_n=10
                                     )

# %%
colnames(sr@meta.data)
# Out:
#   [1] "cell.id"                       "cell.type"
#   [3] "tissue"                        "facs"
#   [5] "donor"                         "isHBV"
#   [7] "isHCV"                         "histology"
#   [9] "ExonicReads"                   "ExonicReadsPer"
#  [11] "IntronicReads"                 "IntronicReadsPer"
#  [13] "IntergenicReads"               "IntergenicReadsPer"
#  [15] "sum"                           "detected"
#  [17] "percent_top_50"                "percent_top_100"
#  [19] "percent_top_200"               "percent_top_500"
#  [21] "subsets_mito_sum"              "subsets_mito_detected"
#  [23] "subsets_mito_percent"          "subsets_HBV_sum"
#  [25] "subsets_HBV_detected"          "subsets_HBV_percent"
#  [27] "total"                         "Sample"
#  [29] "sizeFactor"                    "leiden_global"
#  [31] "leiden_global_celltype"        "leiden_sub"
#  [33] "celltype_old"                  "has_cnv_chr1"
#  [35] "has_loss_chr1"                 "has_dupli_chr1"
#  [37] "proportion_cnv_chr1"           "proportion_loss_chr1"
#  [39] "proportion_dupli_chr1"         "proportion_scaled_cnv_chr1"
#  [41] "proportion_scaled_loss_chr1"   "proportion_scaled_dupli_chr1"
#  [43] "has_cnv_chr2"                  "has_loss_chr2"
#  [45] "has_dupli_chr2"                "proportion_cnv_chr2"
#  [47] "proportion_loss_chr2"          "proportion_dupli_chr2"
#  [49] "proportion_scaled_cnv_chr2"    "proportion_scaled_loss_chr2"
#  [51] "proportion_scaled_dupli_chr2"  "has_cnv_chr3"
#  [53] "has_loss_chr3"                 "has_dupli_chr3"
#  [55] "proportion_cnv_chr3"           "proportion_loss_chr3"
#  [57] "proportion_dupli_chr3"         "proportion_scaled_cnv_chr3"
#  [59] "proportion_scaled_loss_chr3"   "proportion_scaled_dupli_chr3"
#  [61] "has_cnv_chr4"                  "has_loss_chr4"
#  [63] "has_dupli_chr4"                "proportion_cnv_chr4"
#  [65] "proportion_loss_chr4"          "proportion_dupli_chr4"
#  [67] "proportion_scaled_cnv_chr4"    "proportion_scaled_loss_chr4"
#  [69] "proportion_scaled_dupli_chr4"  "has_cnv_chr5"
#  [71] "has_loss_chr5"                 "has_dupli_chr5"
#  [73] "proportion_cnv_chr5"           "proportion_loss_chr5"
#  [75] "proportion_dupli_chr5"         "proportion_scaled_cnv_chr5"
#  [77] "proportion_scaled_loss_chr5"   "proportion_scaled_dupli_chr5"
#  [79] "has_cnv_chr6"                  "has_loss_chr6"
#  [81] "has_dupli_chr6"                "proportion_cnv_chr6"
#  [83] "proportion_loss_chr6"          "proportion_dupli_chr6"
#  [85] "proportion_scaled_cnv_chr6"    "proportion_scaled_loss_chr6"
#  [87] "proportion_scaled_dupli_chr6"  "has_cnv_chr7"
#  [89] "has_loss_chr7"                 "has_dupli_chr7"
#  [91] "proportion_cnv_chr7"           "proportion_loss_chr7"
#  [93] "proportion_dupli_chr7"         "proportion_scaled_cnv_chr7"
#  [95] "proportion_scaled_loss_chr7"   "proportion_scaled_dupli_chr7"
#  [97] "has_cnv_chr8"                  "has_loss_chr8"
#  [99] "has_dupli_chr8"                "proportion_cnv_chr8"
# [101] "proportion_loss_chr8"          "proportion_dupli_chr8"
# [103] "proportion_scaled_cnv_chr8"    "proportion_scaled_loss_chr8"
# [105] "proportion_scaled_dupli_chr8"  "has_cnv_chr9"
# [107] "has_loss_chr9"                 "has_dupli_chr9"
# [109] "proportion_cnv_chr9"           "proportion_loss_chr9"
# [111] "proportion_dupli_chr9"         "proportion_scaled_cnv_chr9"
# [113] "proportion_scaled_loss_chr9"   "proportion_scaled_dupli_chr9"
# [115] "has_cnv_chr10"                 "has_loss_chr10"
# [117] "has_dupli_chr10"               "proportion_cnv_chr10"
# [119] "proportion_loss_chr10"         "proportion_dupli_chr10"
# [121] "proportion_scaled_cnv_chr10"   "proportion_scaled_loss_chr10"
# [123] "proportion_scaled_dupli_chr10" "has_cnv_chr11"
# [125] "has_loss_chr11"                "has_dupli_chr11"
# [127] "proportion_cnv_chr11"          "proportion_loss_chr11"
# [129] "proportion_dupli_chr11"        "proportion_scaled_cnv_chr11"
# [131] "proportion_scaled_loss_chr11"  "proportion_scaled_dupli_chr11"
# [133] "has_cnv_chr12"                 "has_loss_chr12"
# [135] "has_dupli_chr12"               "proportion_cnv_chr12"
# [137] "proportion_loss_chr12"         "proportion_dupli_chr12"
# [139] "proportion_scaled_cnv_chr12"   "proportion_scaled_loss_chr12"
# [141] "proportion_scaled_dupli_chr12" "has_cnv_chr13"
# [143] "has_loss_chr13"                "has_dupli_chr13"
# [145] "proportion_cnv_chr13"          "proportion_loss_chr13"
# [147] "proportion_dupli_chr13"        "proportion_scaled_cnv_chr13"
# [149] "proportion_scaled_loss_chr13"  "proportion_scaled_dupli_chr13"
# [151] "has_cnv_chr14"                 "has_loss_chr14"
# [153] "has_dupli_chr14"               "proportion_cnv_chr14"
# [155] "proportion_loss_chr14"         "proportion_dupli_chr14"
# [157] "proportion_scaled_cnv_chr14"   "proportion_scaled_loss_chr14"
# [159] "proportion_scaled_dupli_chr14" "has_cnv_chr15"
# [161] "has_loss_chr15"                "has_dupli_chr15"
# [163] "proportion_cnv_chr15"          "proportion_loss_chr15"
# [165] "proportion_dupli_chr15"        "proportion_scaled_cnv_chr15"
# [167] "proportion_scaled_loss_chr15"  "proportion_scaled_dupli_chr15"
# [169] "has_cnv_chr16"                 "has_loss_chr16"
# [171] "has_dupli_chr16"               "proportion_cnv_chr16"
# [173] "proportion_loss_chr16"         "proportion_dupli_chr16"
# [175] "proportion_scaled_cnv_chr16"   "proportion_scaled_loss_chr16"
# [177] "proportion_scaled_dupli_chr16" "has_cnv_chr17"
# [179] "has_loss_chr17"                "has_dupli_chr17"
# [181] "proportion_cnv_chr17"          "proportion_loss_chr17"
# [183] "proportion_dupli_chr17"        "proportion_scaled_cnv_chr17"
# [185] "proportion_scaled_loss_chr17"  "proportion_scaled_dupli_chr17"
# [187] "has_cnv_chr18"                 "has_loss_chr18"
# [189] "has_dupli_chr18"               "proportion_cnv_chr18"
# [191] "proportion_loss_chr18"         "proportion_dupli_chr18"
# [193] "proportion_scaled_cnv_chr18"   "proportion_scaled_loss_chr18"
# [195] "proportion_scaled_dupli_chr18" "has_cnv_chr19"
# [197] "has_loss_chr19"                "has_dupli_chr19"
# [199] "proportion_cnv_chr19"          "proportion_loss_chr19"
# [201] "proportion_dupli_chr19"        "proportion_scaled_cnv_chr19"
# [203] "proportion_scaled_loss_chr19"  "proportion_scaled_dupli_chr19"
# [205] "has_cnv_chr20"                 "has_loss_chr20"
# [207] "has_dupli_chr20"               "proportion_cnv_chr20"
# [209] "proportion_loss_chr20"         "proportion_dupli_chr20"
# [211] "proportion_scaled_cnv_chr20"   "proportion_scaled_loss_chr20"
# [213] "proportion_scaled_dupli_chr20" "has_cnv_chr21"
# [215] "has_loss_chr21"                "has_dupli_chr21"
# [217] "proportion_cnv_chr21"          "proportion_loss_chr21"
# [219] "proportion_dupli_chr21"        "proportion_scaled_cnv_chr21"
# [221] "proportion_scaled_loss_chr21"  "proportion_scaled_dupli_chr21"
# [223] "has_cnv_chr22"                 "has_loss_chr22"
# [225] "has_dupli_chr22"               "proportion_cnv_chr22"
# [227] "proportion_loss_chr22"         "proportion_dupli_chr22"
# [229] "proportion_scaled_cnv_chr22"   "proportion_scaled_loss_chr22"
# [231] "proportion_scaled_dupli_chr22" "top_loss_1"
# [233] "top_loss_2"                    "top_loss_3"
# [235] "top_loss_4"                    "top_loss_5"
# [237] "top_loss_6"                    "top_loss_7"
# [239] "top_loss_8"                    "top_loss_9"
# [241] "top_loss_10"                   "top_dupli_1"
# [243] "top_dupli_2"                   "top_dupli_3"
# [245] "top_dupli_4"                   "top_dupli_5"
# [247] "top_dupli_6"                   "top_dupli_7"
# [249] "top_dupli_8"                   "top_dupli_9"
# [251] "top_dupli_10"

# %%
DimPlot(sr, reduction = "UMAP", group.by = "donor", label = T)
# Out:
# plot without title

# %%
FeaturePlot(sr, reduction="UMAP", features="has_loss_chr16", pt.size = 3) + ggplot2::scale_colour_distiller(palette = "Reds", direction = 1, limits=c(0,1))
# Out:
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
# plot without title

# %%
FeaturePlot(sr, reduction="UMAP", features="proportion_scaled_dupli_chr5", pt.size = 3) + ggplot2::scale_colour_distiller(palette = "Reds", direction = 1, limits=c(0,1))
# Out:
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
# plot without title
